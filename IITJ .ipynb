# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image_dataset_from_directory as idfd
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.layers import MaxPooling2D, Conv2D
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33152\1951775282.py in <module>
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import pandas as pd
#       5 from tensorflow.keras.models import Sequential
#
# ~\anaconda3\envs\hari\lib\site-packages\tensorflow\__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# ~\anaconda3\envs\hari\lib\site-packages\tensorflow\python\__init__.py in <module>
#      35
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      38
#      39 # pylint: enable=wildcard-import
#
# ...

# %%
#Reset the parameters and clear the last session. Usually done before making a new model
tf.keras.backend.clear_session()

# %%
label=pd.read_csv("H:/Research Datasets/IITJ Problem Solving/charts_unzipped/train_val.csv")

# %%
labels=label["type"]

# %%
path="H:/Research Datasets/IITJ Problem Solving/charts_unzipped/train_val"
files=[]
files_l=os.listdir(path)
for i in range(0,len(os.listdir(path))):
    img=plt.imread(os.path.join(path,files_l[i]))
    files.append(img)
files=np.array(files)

# %%
X_train, X_val, ytrain, yval = train_test_split(files,labels, test_size=0.2, random_state=3, stratify=labels)

# %%
labelencoder=LabelEncoder()
labelencoder.fit(ytrain)
y_train=labelencoder.transform(ytrain)
labelencoder.fit(yval)
y_val=labelencoder.transform(yval)

# %%
X_train=np.stack(tuple(X_train))
X_val=np.stack(tuple(X_val))

# %%
X_train[1].shape
# Out:
# (128, 128, 4)

# %%
tf.keras.backend.clear_session()
model=Sequential([Conv2D(128, (3,3), activation="leaky_relu", input_shape=(128,128,4,)),
                  MaxPooling2D(2,2),
                  Conv2D(64, (3,3), activation="leaky_relu"),
                  MaxPooling2D(2,2),
                  Flatten(),
                  Dense(32, activation="relu"),
                  Dense(5, activation="softmax")
])

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=200, validation_split=0.2)
# Out:
# Epoch 1/200
# 20/20 [==============================] - 1s 39ms/step - loss: 2.4043 - accuracy: 0.2047 - val_loss: 1.6237 - val_accuracy: 0.2000
# Epoch 2/200
# 20/20 [==============================] - 1s 34ms/step - loss: 1.5800 - accuracy: 0.2344 - val_loss: 1.5105 - val_accuracy: 0.3063
# Epoch 3/200
# 20/20 [==============================] - 1s 35ms/step - loss: 1.4491 - accuracy: 0.3234 - val_loss: 1.4919 - val_accuracy: 0.3125
# Epoch 4/200
# 20/20 [==============================] - 1s 35ms/step - loss: 1.3620 - accuracy: 0.3328 - val_loss: 1.4292 - val_accuracy: 0.4187
# Epoch 5/200
# 20/20 [==============================] - 1s 35ms/step - loss: 1.3374 - accuracy: 0.4172 - val_loss: 1.3095 - val_accuracy: 0.4500
# Epoch 6/200
# 20/20 [==============================] - 1s 35ms/step - loss: 1.2147 - accuracy: 0.5203 - val_loss: 1.2184 - val_accuracy: 0.5125
# Epoch 7/200
# ...

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train","val"],loc="upper left")
plt.show()

# %%
model.evaluate(X_val,y_val)
# Out:
# 7/7 [==============================] - 0s 20ms/step - loss: 6.7746 - accuracy: 0.5850
# [6.774592876434326, 0.5849999785423279]

# %%
testimg
# Out:
# ['0.png',
#  '1.png',
#  '10.png',
#  '11.png',
#  '12.png',
#  '13.png',
#  '14.png',
#  '15.png',
#  '16.png',
#  '17.png',
#  '18.png',
#  '19.png',
#  '2.png',
#  '20.png',
#  '21.png',
#  '22.png',
#  '23.png',
#  '24.png',
#  '25.png',
#  '26.png',
#  '27.png',
#  '28.png',
#  '29.png',
#  '3.png',
#  '30.png',
#  '31.png',
#  '32.png',
#  '33.png',
#  '34.png',
#  '35.png',
#  '36.png',
#  '37.png',
#  '38.png',
#  '39.png',
#  '4.png',
#  '40.png',
#  '41.png',
#  '42.png',
#  '43.png',
#  '44.png',
#  '45.png',
#  '46.png',
#  '47.png',
#  '48.png',
#  '49.png',
#  '5.png',
#  '6.png',
#  '7.png',
#  '8.png',
#  '9.png']

# %%
testdir="H:/Research Datasets/IITJ Problem Solving/charts_unzipped/test"
testimg=os.listdir(testdir)
testf=[]
for i in testimg:
    testf.append(plt.imread(os.path.join(testdir,i)))
testf=np.array(testf)

# %%
import torchvision.models as models
alexnet_model = models.alexnet(pretrained=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40260\1580106100.py in <cell line: 1>()
# ----> 1 import torchvision.models as models
#       2 alexnet_model = models.alexnet(pretrained=True)
#
# ModuleNotFoundError: No module named 'torchvision'
